# %%
#######################################################################################################################################
######### CRIADO POR      :  MIRIAM OLIVEIRA, LAURO MIRANDA E RAFAEL OLIVEIRA                                                 #########
######### CÓDIGO ADAPTADO :  https://colab.research.google.com/drive/1GXmk1v8C-c4UtyKFqIm9HnsrVYH0pI-c                        #########
######### OBJETIVO      :  EFETUAR A LEITURA DE UMA LISTA DE LIGANTES QUE SERÃO TESTADOS PARA O RECEPTOR 5U1L                 #########
#########                  UTILIZANDO A BIBLIOTECA GNINA. OS DADOS SALVOS SERÃO EXPORTADOS PARA UM ARQUIVO DE SAÍDA           #########
######### DATA          :  24/08/2021                                                                                         #########
######### ARQUIVO DE ENTRADA : LIGANTES.XLSX       (CLICAR COM O BOTÃO DIREITO EM FILES E FAZER UPLOAD DESTE ARQUIVO)         #########
######### ARQUIVO DE SAÍDA   : GNINA_SCORE_RECEPTOR_LIGANTES.csv  (SERÁ SALVO AUTOMATICAMENTE E DISPONIBLIZADO POR DOWNLOAD) #########
###############################################################################################################V#######################
# !pip install xlrd
# !pip install pandas
# !pip install rdkit-pypi #biblioteca usada para manipular e gerar moleculas 3d
import xlrd           #biblioteca usada para manipular arquivo excell
import pandas as pd   #biblioteca usada para ler os resultados
import subprocess, io, re  #bibliotecas para extração dos resultados do arquivo txt por palavras chave (que contém o score)
from rdkit import Chem #biblioteca usada para manipular e gerar moleculas 3d
from rdkit.Chem import AllChem #biblioteca usada para manipular e gerar moleculas 3d

################################################################################
# INSTALL CONDA ON GOOGLE COLAB
################################################################################
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local

! conda install -q -y -c conda-forge openbabel

import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')

# !pip install py3Dmol

# !wget https://downloads.sourceforge.net/project/smina/smina.static

# !wget https://github.com/gnina/gnina/releases/download/v1.0.1/gnina

# !chmod +x gnina

# !./gnina
# Out:
# ...
# --2024-08-21 00:17:17--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh.3’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M  11.2MB/s    in 7.4s
#
# 2024-08-21 00:17:24 (11.0 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh.3’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# ./Miniconda3-py37_4.8.2-Linux-x86_64.sh: line 392: /usr/local/conda.exe: Permission denied
# chmod: cannot access '/usr/local/conda.exe': No such file or directory
# Unpacking payload ...
# ./Miniconda3-py37_4.8.2-Linux-x86_64.sh: line 404: /usr/local/conda.exe: No such file or directory
# ...

# %%
#LEITURA DO ARQUIVO LIGANTES.XLSX  (MUDE O NOME DO ARQUIVO NESTE PONTO!)

ArqListaLigantes='./Planilha_Ambinter.xls'  # para executar tudo de uma vez

# Altere o 0 para a linha onde os dados começam a ser exibidos
tabela = xlrd.open_workbook(ArqListaLigantes).sheet_by_index(0)
qtd_linhas = tabela.nrows

print("TOTAL DE LIGANTES: " + str(qtd_linhas))
print("\n")

data = []
# Out:
# TOTAL DE LIGANTES: 100

# %%
data = []

try:
      #for linha in range(1,qtd_linhas):
      # Altere o 0 para a linha onde os dados começam a ser exibidos
    for linha in range(0 ,qtd_linhas):
      # Altere os índices a baixo de acordo com a localização das colunas na tabela, lembrando a primeira é 0, segunda 1, assim por diante
      grupoMolecula = tabela.row(linha)[0].value.strip()  #LER COLUNA GRUPO
      nomeMolecula = tabela.row(linha)[1].value.strip() #LER COLUNA MOLECULA
      smileMolecula = tabela.row(linha)[2].value.strip() #LER COLUNA SMILE


      # RECUPERAR DADOS
      print("=======================================INÍCIO DO PROCESSAMENTO===========================================")
      print("\n")
      print("GRUPO: " + grupoMolecula)
      print("MOLECULA: " + nomeMolecula)
      print("SMILE: " + smileMolecula)
      print("\n")


      #GRAVAR ARQUIVO SMILE
      arquivo = open("smile.txt", "w")  #sempre irá substitutuir o conteúdo existente
      arquivo.write(smileMolecula)
      arquivo.close()

      #CONVERTE SDF
      #!obabel -: smile.smi -O ligante.sdf --gen3D
      #!obabel -: smile.smi -O ligante.sdf --gen2D

      f = open("smile.txt", "r")
      smiles = f.read()

# Convertendo a representação SMILES para um objeto de molécula RDKit
      molecule = Chem.MolFromSmiles(smiles)
#       if molecule is not None:  # Verifica se a molécula foi carregada corretamente

      molecule = Chem.AddHs(molecule)
      AllChem.EmbedMolecule(molecule, AllChem.ETKDG())
      AllChem.UFFOptimizeMolecule(molecule, maxIters=100)
      with open('molecule.sdf', 'a') as f:  # Abre o arquivo em modo de acréscimo
            f.write(Chem.MolToMolBlock(molecule))

     # molecule = Chem.SmilesMolSupplier('smile.smi')
      #for molecule in supplier:
      #  if molecule is not None:  # Verifica se a molécula foi carregada corretamente
      #   molecule = Chem.AddHs(molecule)
      #  AllChem.EmbedMolecule(molecule, AllChem.ETKDG())
      #  AllChem.UFFOptimizeMolecule(molecule, maxIters=100)
      #with open('molecule.sdf', 'a') as f:
      #  f.write(Chem.MolToMolBlock(molecule))
     # print(Chem.MolToMolBlock(molecule),file=open('molecule.sdf','w+'))
#
      #EXECUTA GNINA E GRAVA A SAÍDA (RESULTADOS) NO ARQUIVO SCORES.TXT
      #Forma Sítio alostérico (relatório)
      #!./gnina -r /content/Maestro_hp2x7p_alphafold_trimerico.pdb -l molecule.sdf --center_x 175.206 --center_y 168.196 --center_z 220.025 --size_x 26 --size_y 68 --size_z 30 > scores.txt 2>&1
      #!./gnina -r 6u9vP2X7.pdb -l ligante.sdf --center_x 163 --center_y 173 --center_z 219 --size_x 40 --size_y 30 --size_z 30 --seed -1985 > scores.txt 2>&1

      #EXIBE RESULTADO
      #!head -n 50 scores.txt

      #2. FORMA sítio alostérico
      #  !./gnina -r rec.pdb -l lig.pdb --autobox_ligand lig.pdb -o docked.sdf --seed 0

      #3. FORMA  sítio ortoestérico
      #!./gnina -r P2X7_preparado_.pdb -l ligante.sdf --center_x 185.206 --center_y 163.196 --center_z 220.025 --size_x 44 --size_y 52 --size_z 44 --seed -1985 --score_only --custom_scoring everything.txt > scores.txt 2>&1
      # !./gnina -r ./Maestro_hp2x7p_alphafold_trimerico.pdb -l molecule.sdf --center_x -7.218 --center_y -44.877 --center_z -2.503 --size_x 50 --size_y 40 --size_z 40 --seed -1985 > scores.txt 2>&1

      #--cnn crossdock_default2018

      # Abre o arquivo de scores
      with open("scores.txt", "r") as file:
          #Define uma variável linhas e nela ficam todas as linhas do arquivo
         lines = file.readlines()
      # Intera sobre cada linha da variável linhas
      for line in lines:
          # Remove o espaçamento desnecessário
        line = line.strip()
          # REGEX para encontrar a linha com as linhas com os dados
        if re.match(r"\s*\d+\s+[-+]?\d+\.\d+\s+[-+]?\d+\.\d+\s+[-+]?\d+\.\d+", line):
                  # Separa a linha de dados em colunas
                  columns = line.split()
                  mode = int(columns[0])
                  affinity = float(columns[1])
                  cnn_score = float(columns[2])
                  cnn_affinity = float(columns[3])
                  # Acrescenta as informações a um array
                  data.append((mode, affinity, cnn_score, cnn_affinity, "Success", smileMolecula, grupoMolecula, nomeMolecula))

# Em caso de erro, acrescenta um erro ao array
except Exception as e:
    print(e)
    data.append(("N/A", "N/A", "N/A", "N/A", "Error", "N/A", "N/A", "N/A"))



# Converte scores em DataFrame
scores_df = pd.DataFrame(data, columns=['Mode', 'Affinity', 'CNN Score', 'CNN Affinity', 'Status', "Smile", "Molecule Group", "Molecule Name"])

scores_df

# Converte DataFrame em Excel
scores_df.to_excel('scores.xlsx', index=False)

# Baixa Excel
files.download('scores.xlsx')
# Out:
# =======================================INÍCIO DO PROCESSAMENTO===========================================
#
#
# GRUPO: Amb10069245
# MOLECULA: ZINC000001690027
# SMILE: CC(=O)c1cccc(C)n1
#
#
# =======================================INÍCIO DO PROCESSAMENTO===========================================
#
#
# GRUPO: Amb10069355
# MOLECULA: ZINC000001549593
# SMILE: O=C(O)[C@H](O)[C@H](O)[C@@H](O)[C@@H](O)C(=O)O
#
#
# =======================================INÍCIO DO PROCESSAMENTO===========================================
#
#
# GRUPO: Amb10069355
# MOLECULA: ZINC000003581021
# SMILE: O=C(O)[C@H](O)[C@@H](O)[C@@H](O)[C@@H](O)C(=O)O
#
#
# =======================================INÍCIO DO PROCESSAMENTO===========================================
#
#
# GRUPO: Amb10069355
# MOLECULA: ZINC000006072527
# SMILE: O=C(O)[C@@H](O)[C@@H](O)[C@@H](O)[C@@H](O)C(=O)O
#
#
# =======================================INÍCIO DO PROCESSAMENTO===========================================
#
#
# GRUPO: Amb10069355
# ...

# %%
# Converte scores em DataFrame
scores_df = pd.DataFrame(data, columns=['Mode', 'Affinity', 'CNN Score', 'CNN Affinity', 'Status', "Smile", "Molecule Group", "Molecule Name"])

scores_df

# Converte DataFrame em Excel
scores_df.to_excel('scores.xlsx', index=False)

# Baixa Excel
files.download('scores.xlsx')
